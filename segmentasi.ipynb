# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
len(flags)
258
flags[40]
'COLOR_BGR2RGB'
gambar = cv2.imread(r'C:\Users\Lenovo\Desktop\myresearch\Ipynb\s2.jpg')
plt.imshow(gambar)
plt.show()

# %%
gambar = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)
plt.imshow(gambar)
plt.show()

# %%
hsv_gmbr = cv2.cvtColor(gambar, cv2.COLOR_RGB2HSV)

# %%
mask = cv2.inRange(hsv_gmbr, light_orange, dark_orange)
result = cv2.bitwise_and(gambar, gambar, mask=mask)

# %%
plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(result)
plt.show()
