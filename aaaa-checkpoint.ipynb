# %%
import PIL

# %%
from PIL import Image

# %%
img = Image.open('C:\\Users\\Lenovo\\Desktop\\myresearch\\PI\\pdf\\New folder (2)\\steve.jpg','r')

# %%
pix = list(img.getdata())
pix
# Out:
# [(47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (47, 32, 13),
#  (45, 32, 15),
#  (45, 32, 15),
#  (45, 32, 15),
#  (44, 31, 14),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (42, 29, 12),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
#  (43, 30, 13),
# ...

# %%
def
